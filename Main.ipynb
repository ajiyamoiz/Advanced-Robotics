# %% [markdown]
# <a href="https://colab.research.google.com/github/ajiyamoiz/Advanced-Robotics/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, files
drive.mount('/content/drive/')
path = "/content/drive/MyDrive/Colab Notebooks/Advanced Robotics/Assignment 2/"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ### Set up the Environment

# %%
import numpy as np
import cv2 as cv
import math
import matplotlib.pyplot as plt
from scipy.linalg import svd
from IPython.core.debugger import set_trace

# %% [markdown]
# ### Read the left and right image

# %%
imgL = cv.imread(path + "images/left.png")
gray1 = cv.cvtColor(imgL, cv.COLOR_BGR2GRAY)

# %%
imgR = cv.imread(path + "images/right.png")
gray2 = cv.cvtColor(imgR, cv.COLOR_BGR2GRAY)

# %%
plt.subplot(121), plt.imshow(imgL), plt.show()
plt.subplot(122), plt.imshow(imgR), plt.show()
# Out:
# (<Axes: >, <matplotlib.image.AxesImage at 0x7f186c2f98b0>, None)

# %% [markdown]
# ### Read the left and right image coordinates from the given text files

# %%
def get_coordinates(filename):
    with open(filename,'r+') as f:
        lines = f.read().splitlines()
    coordinates = []
    for l in lines:
        v, u = l.split()
        coordinates.append((float(u), float(v)))
    return coordinates

# %%
kps1 = get_coordinates("images/pt_2D_left.txt")
kps2 = get_coordinates("images/pt_2D_right.txt")
print("Left and right image keypoints are: ", len(kps1), len(kps2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-98403ccade4a> in <module>
# ----> 1 kps1 = get_coordinates("images/pt_2D_left.txt")
#       2 kps2 = get_coordinates("images/pt_2D_right.txt")
#       3 print("Left and right image keypoints are: ", len(kps1), len(kps2))
#
# <ipython-input-20-a517c3b9832c> in get_coordinates(filename)
#       1 def get_coordinates(filename):
# ----> 2     with open(filename,'r+') as f:
#       3         lines = f.read().splitlines()
#       4     coordinates = []
#       5     for l in lines:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images/pt_2D_left.txt'

# %% [markdown]
# ### Test the correspondances

# %%
(hA, wA) = imgL.shape[:2]
(hB, wB) = imgR.shape[:2]
vis = np.zeros((max(hA, hB), wA + wB, 3), dtype="uint8")
vis[0:hA, 0:wA] = imgL
vis[0:hB, wA:] = imgR

for ((x1, y1), (x2, y2)) in zip(kps1, kps2):
    ptA = (int(x1), int(y1))
    ptB = (int(x2) + wA, int(y2))
    cv.line(vis, ptA, ptB, (0, 255, 0), 1)

plt.imshow(vis), plt.show
_ = cv.imwrite("results/given_correspondances_vis.jpg", vis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-275092705e04> in <module>
#       5 vis[0:hB, wA:] = imgR
#       6
# ----> 7 for ((x1, y1), (x2, y2)) in zip(kps1, kps2):
#       8     ptA = (int(x1), int(y1))
#       9     ptB = (int(x2) + wA, int(y2))
#
# TypeError: cannot unpack non-iterable cv2.KeyPoint object

# %% [markdown]
# ## Estimating Fundamental Matrix using Normalized 8-Point Algorithm

# %%
# Convert to homogenous coordinates
kps1 = np.concatenate((kps1,np.ones((len(kps1),1))), axis = 1)
kps2 = np.concatenate((kps2,np.ones((len(kps2),1))), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-23-4d8cc8060103> in <module>
#       1 # Convert to homogenous coordinates
# ----> 2 kps1 = np.concatenate((kps1,np.ones((len(kps1),1))), axis = 1)
#       3 kps2 = np.concatenate((kps2,np.ones((len(kps2),1))), axis = 1)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
def normalize_points(kps):
    mean = np.mean(kps, axis=0)
    centered = kps - mean * np.ones(kps.shape)
    squared = centered * centered
    distance = np.sqrt(squared[:, 0] + squared[:, 1])
    std = np.mean(distance)
    Tr1 = np.array([[1, 0, -mean[0]], [0, 1, -mean[1]], [0, 0, 1]])
    Tr2 = np.array([[math.sqrt(2) / std, 0, 0], [0, math.sqrt(2) / std, 0], [0, 0, 1]])
    Tr = Tr2 @ Tr1
    return ((Tr @ kps.T).T, Tr)

# %%
p1, Tr_p1 = normalize_points(kps1)
p2, Tr_p2 = normalize_points(kps2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-fb7b72e8c5cf> in <module>
# ----> 1 p1, Tr_p1 = normalize_points(kps1)
#       2 p2, Tr_p2 = normalize_points(kps2)
#
# <ipython-input-24-39910b5825eb> in normalize_points(kps)
#       1 def normalize_points(kps):
# ----> 2     mean = np.mean(kps, axis=0)
#       3     centered = kps - mean * np.ones(kps.shape)
#       4     squared = centered * centered
#       5     distance = np.sqrt(squared[:, 0] + squared[:, 1])
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in mean(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3472             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3473
# -> 3474     return _methods._mean(a, axis=axis, dtype=dtype,
#    3475                           out=out, **kwargs)
#    3476
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     177             is_float16_result = True
#     178
# --> 179     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     180     if isinstance(ret, mu.ndarray):
#     181         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'cv2.KeyPoint' and 'cv2.KeyPoint'

# %%
def estimate_fundamental_matrix(p1, p2):
    # Linear Solution
    A_list = []
    for i in range(p1.shape[0]):
        u1 = p1[i][0]
        v1 = p1[i][1]
        u2 = p2[i][0]
        v2 = p2[i][1]

        # u1u1' v1u1' u1' u1v1' v1v1' v1' u1 v1 1
        # u1u2  v1u2  u2  u1v2  v1v2  v2  u1 v1 1
        A_list.append([u1*u2, v1*u2, u2, u1*v2, v1*v2, v2, u1, v1, 1])
    A = np.array(A_list)
    _, _, Vt = svd(A, full_matrices=False, overwrite_a=True)
    f = Vt[-1].reshape(3,3)

    # Enforce 2-rank constraint
    s, v, d = svd(f, full_matrices=False, overwrite_a=True)
    f_hat = s @ np.diag([*v[:2], 0]) @ d
    print("Determinant of f_hat is: ", np.linalg.det(f_hat))
    return f_hat

# %%
f_hat = estimate_fundamental_matrix(p1, p2)
# f_hat = estimate_fundamental_matrix(kps1, kps2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-92c27abbdda2> in <module>
# ----> 1 f_hat = estimate_fundamental_matrix(p1, p2)
#       2 # f_hat = estimate_fundamental_matrix(kps1, kps2)
#
# NameError: name 'p1' is not defined

# %%
F = Tr_p2.T @ f_hat @ Tr_p1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8b925dd1e521> in <module>
# ----> 1 F = Tr_p2.T @ f_hat @ Tr_p1
#
# NameError: name 'Tr_p2' is not defined

# %%
F
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-f4d604803730> in <module>
# ----> 1 F
#
# NameError: name 'F' is not defined

# %% [markdown]
# ### Visualise the Epipolar Lines

# %%
def drawlines(img1,img2,lines,pts1,pts2):
    ''' img1 - image on which we draw the epilines for the points in img2
        lines - corresponding epilines '''
    r,c, _ = img1.shape
    for r,pt1,pt2 in zip(lines,pts1,pts2):
        color = tuple(np.random.randint(0,255,3).tolist())
        x0,y0 = map(int, [0, -r[2]/r[1] ])
        x1,y1 = map(int, [c, -(r[2]+r[0]*c)/r[1] ])
        img1 = cv.line(img1, (x0,y0), (x1,y1), color,1)
        img1 = cv.circle(img1,tuple(pt1),5,color,-1)
        img2 = cv.circle(img2,tuple(pt2),5,color,-1)
    return img1,img2

# %%
def vis_epipolar_lines(kps1, kps2, F, imgL, imgR, tag):

    pts1 = np.int32(kps1[:, 0:2])
    pts2 = np.int32(kps2[:, 0:2])

    # Find epilines corresponding to points in right image (second image) and
    # drawing its lines on left image
    lines1 = cv.computeCorrespondEpilines(pts2.reshape(-1,1,2), 2,F)
    lines1 = lines1.reshape(-1,3)
    img5,img6 = drawlines(imgL,imgR,lines1,pts1,pts2)

    lines2 = cv.computeCorrespondEpilines(pts1.reshape(-1,1,2), 1,F)
    lines2 = lines2.reshape(-1,3)
    img3,img4 = drawlines(imgR,imgL,lines2,pts2,pts1)

    plt.subplot(121),plt.imshow(img5)
    plt.subplot(122),plt.imshow(img3)
    plt.show()

    _ = cv.imwrite("output/left_epilines_"+tag+".jpg", img5)
    _ = cv.imwrite("output/right_epilines_"+tag+".jpg", img3)

    return lines1, lines2

# %%
lines1, lines2 = vis_epipolar_lines(kps1, kps2, F, imgL, imgR, tag="custom")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4b65b167398d> in <module>
# ----> 1 lines1, lines2 = vis_epipolar_lines(kps1, kps2, F, imgL, imgR, tag="custom")
#
# NameError: name 'F' is not defined

# %% [markdown]
# ## Estimate the error

# %%
def line_to_point_distance(point, line):
    (a, b, c) = line
    (u, v, _) = point
    return np.abs(a*u + b*v + c/np.sqrt(a*a + b*b))

# %%
def avg_epipolar_dist(points, lines):
    distance = 0
    for i in range(points.shape[0]):
        distance = distance + line_to_point_distance(points[i], lines[i])
    return distance/points.shape[0]

# %%
print("Estimation Error(image 1):", avg_epipolar_dist(kps1, lines1))
print("Estimation Error(image 2):", avg_epipolar_dist(kps2, lines2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-9461ed0fa477> in <module>
# ----> 1 print("Estimation Error(image 1):", avg_epipolar_dist(kps1, lines1))
#       2 print("Estimation Error(image 2):", avg_epipolar_dist(kps2, lines2))
#
# NameError: name 'lines1' is not defined

# %% [markdown]
# ## Test the performance with noise in the image point correspondences

# %%
# Add noise of Gaussian distribution with given mean and standard deviation
def generate_noisy_2d_points(x, mean, std_dev):
    noise = np.random.normal(mean, std_dev, x.shape)
    noisy_x = x + noise
    return np.concatenate((noisy_x, np.ones((x.shape[0], 1))), axis=1)

# %%
std_dev_list = [0.5, 1, 1.5, 2]

# %%
print("For noisy points:")
for i in range(len(std_dev_list)):
    deviation = std_dev_list[i]
    print("========With Noise of mean:0 and std dev:", deviation, ":==========")
    kps1_noisy = generate_noisy_2d_points(kps1[:, 0:2], 0, deviation)
    kps2_noisy = generate_noisy_2d_points(kps2[:, 0:2], 0, deviation)
    p1, Tr_p1 = normalize_points(kps1_noisy)
    p2, Tr_p2 = normalize_points(kps2_noisy)
    f_hat = estimate_fundamental_matrix(p1, p2)
    F = Tr_p2.T @ f_hat @ Tr_p1
    lines1, lines2 = vis_epipolar_lines(kps1_noisy, kps2_noisy, F, imgL, imgR,tag="std"+str(deviation))
    print("Estimation Error(image 1):", avg_epipolar_dist(kps1_noisy, lines1))
    print("Estimation Error(image 2):", avg_epipolar_dist(kps2_noisy, lines2))
# Out:
# For noisy points:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-479e0b5702a3> in <module>
#       1 print("For noisy points:")
# ----> 2 for i in range(len(std_dev_list)):
#       3     deviation = std_dev_list[i]
#       4     print("========With Noise of mean:0 and std dev:", deviation, ":==========")
#       5     kps1_noisy = generate_noisy_2d_points(kps1[:, 0:2], 0, deviation)
#
# NameError: name 'std_dev_list' is not defined

# %% [markdown]
# # Estimation of the Fundamental Matrix with Detected and Described Features

# %%
sift = cv.SIFT_create(contrastThreshold=0.02)
kps1, descs1 = sift.detectAndCompute(gray1,None)
kps2, descs2 = sift.detectAndCompute(gray2,None)
img1_kps=cv.drawKeypoints(gray1,kps1,imgL)
img2_kps=cv.drawKeypoints(gray2,kps2,imgR)

plt.subplot(121), plt.imshow(img1_kps), plt.show()
plt.subplot(122), plt.imshow(img2_kps), plt.show()
_ = cv.imwrite('output/sift_keypoints_left.jpg',img1_kps)
_ = cv.imwrite('output/sift_keypoints_right.jpg',img2_kps)

# %%
# FLANN parameters
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
search_params = dict(checks=50)
flann = cv.FlannBasedMatcher(index_params,search_params)
matches = flann.knnMatch(descs1,descs2,k=2)

pts1 = []
pts2 = []
# ratio test as per Lowe's paper
for i,(m,n) in enumerate(matches):
    if m.distance < 0.8*n.distance:
        pts2.append(kps2[m.trainIdx].pt)
        pts1.append(kps1[m.queryIdx].pt)

# %%
def convert_to_homogenous_coords(kps):
    points = []
    for i in range(len(kps)):
        points.append([kps[i][0], kps[i][1]])

    # Convert to homogenous coordinates
    return np.concatenate((points,np.ones((len(points),1))), axis = 1)

# %%
points1 = convert_to_homogenous_coords(pts1)
points2 = convert_to_homogenous_coords(pts2)

# %%
p1, Tr_p1 = normalize_points(points1)
p2, Tr_p2 = normalize_points(points2)

# %%
f_hat = estimate_fundamental_matrix(p1, p2)
Fcustom = Tr_p2.T @ f_hat @ Tr_p1
# Out:
# Determinant of f_hat is:  0.0

# %%
lines1, lines2 = vis_epipolar_lines(points1, points2, Fcustom, imgL, imgR, tag="sift")

# %%
print("Estimation Error(image 1):", avg_epipolar_dist(points1, lines1))
print("Estimation Error(image 2):", avg_epipolar_dist(points2, lines2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-5273f7483f76> in <module>
# ----> 1 print("Estimation Error(image 1):", avg_epipolar_dist(points1, lines1))
#       2 print("Estimation Error(image 2):", avg_epipolar_dist(points2, lines2))
#
# <ipython-input-32-2c36d632d1a6> in avg_epipolar_dist(points, lines)
#       2     distance = 0
#       3     for i in range(points.shape[0]):
# ----> 4         distance = distance + line_to_point_distance(points[i], lines[i])
#       5     return distance/points.shape[0]
#
# NameError: name 'line_to_point_distance' is not defined
